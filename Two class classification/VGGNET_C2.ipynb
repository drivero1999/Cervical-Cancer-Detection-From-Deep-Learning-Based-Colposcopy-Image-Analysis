# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.14.0)

# %%
#Librerias
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib.pyplot as plt
import os
import numpy as np
import cv2
import random
from shutil import rmtree
import tensorflow as tf
from sklearn.model_selection import train_test_split
from keras.callbacks import TensorBoard
from keras.utils import to_categorical
#from keras_preprocessing.image import load_img, img_to_array, array_to_img, save_img

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#NHS TIPO NIC1 SEG
#307
image_ids_array = ['I264211_C1.jpg', 'I169320_C2.jpg', 'I166612_C1.jpg', 'I169320_C1.jpg', 'I166612_C2.jpg', 'I150818_C2.jpg', 'I150818_C1.jpg', 'I149745_C2.jpg', 'I149745_C1.jpg', 'I133591_C2.jpg', 'I126100_C1.jpg', 'I133591_C1.jpg', 'I126100_C2.jpg', 'I124361_C1.jpg', 'I103738_C1.jpg', 'I103738_C2.jpg', 'I124361_C2.jpg', 'I124032_C2.jpg', 'I124032_C1.jpg', 'I264211_C2.jpg', 'I342192_C2.jpg', 'I342192_C1.jpg', 'I339977_C2.jpg', 'I335731_C2.jpg', 'I326517_C1.jpg', 'I324210_C2.jpg', 'I339977_C1.jpg', 'I335731_C1.jpg', 'I326517_C2.jpg', 'I324210_C1.jpg', 'I298042_C2.jpg', 'I295650_C1.jpg', 'I295650_C2.jpg', 'I293440_C1.jpg', 'I274386_C2.jpg', 'I293440_C2.jpg', 'I313616_C2.jpg', 'I298042_C1.jpg', 'I313616_C1.jpg', 'I274386_C1.jpg', 'I522521_C1.jpg', 'I517492_C2.jpg', 'I493937_C1.jpg', 'I493937_C2.jpg', 'I517492_C1.jpg', 'I505766_C2.jpg', 'I505766_C1.jpg', 'I474789_C1.jpg', 'I478042_C1.jpg', 'I478042_C2.jpg', 'I474789_C2.jpg', 'I466728_C2.jpg', 'I466728_C1.jpg', 'I437637_C1.jpg', 'I437637_C2.jpg', 'I371059_C2.jpg', 'I368134_C2.jpg', 'I368134_C1.jpg', 'I371059_C1.jpg', 'I352381_C2.jpg', 'I352381_C1.jpg', 'I635482_C1.jpg', 'I633710_C1.jpg', 'I633710_C2.jpg', 'I630618_C1.jpg', 'I630618_C2.jpg', 'I608976_C2.jpg', 'I608935_C1.jpg', 'I608976_C1.jpg', 'I608935_C2.jpg', 'I595301_C2.jpg', 'I592231_C2.jpg', 'I592231_C1.jpg', 'I595301_C1.jpg', 'I584458_C1.jpg', 'I584458_C2.jpg', 'I580816_C1.jpg', 'I580149_C1.jpg', 'I580816_C2.jpg', 'I580149_C2.jpg', 'I545787_C2.jpg', 'I579989_C1.jpg', 'I535966_C2.jpg', 'I545787_C1.jpg', 'I579989_C2.jpg', 'I535966_C1.jpg', 'I527027_C1.jpg', 'I527027_C2.jpg', 'I522521_C2.jpg', 'I743469_C1.jpg', 'I743435_C2.jpg', 'I704275_C2.jpg', 'I743333_C1.jpg', 'I677963_C1.jpg', 'I702418_C1.jpg', 'I691209_C2.jpg', 'I743333_C2.jpg', 'I702418_C2.jpg', 'I704275_C1.jpg', 'I691209_C1.jpg', 'I677963_C2.jpg', 'I662039_C1.jpg', 'I643611_C1.jpg', 'I672531_C1.jpg', 'I662039_C2.jpg', 'I672531_C2.jpg', 'I668441_C2.jpg', 'I668441_C1.jpg', 
C2.jpg', 'I745165_C2.jpg', 'I745165_C1.jpg', 'I745232_C1.jpg', 'I746524_C1.jpg', 'I746431_C1.jpg', 'I746360_C2.jpg', 'I746360_C1.jpg', 'I746308_C2.jpg', 'I746308_C1.jpg', 'I746274_C2.jpg', 'I746259_C1.jpg', 'I746123_C1.jpg', 'I746123_C2.jpg', 'I746174_C2.jpg', 'I746072_C1.jpg', 'I746035_C2.jpg', 'I746035_C1.jpg', 'I746072_C2.jpg', 'I745983_C2.jpg', 'I745930_C2.jpg', 'I745957_C1.jpg', 'I745930_C1.jpg', 'I745847_C2.jpg', 'I745886_C2.jpg', 'I745957_C2.jpg', 'I745983_C1.jpg', 'I745964_C2.jpg', 'I745964_C1.jpg', 'I745886_C1.jpg', 'I750994_C1.jpg', 'I747684_C1.jpg', 'I751566_C1.jpg', 'I751566_C2.jpg', 'I753457_C1.jpg', 'I750994_C2.jpg', 'I753457_C2.jpg', 'I747104_C2.jpg', 'I747104_C1.jpg', 'I747028_C2.jpg', 'I746771_C2.jpg', 'I746614_C2.jpg', 'I746614_C1.jpg', 'I746692_C2.jpg', 'I746596_C1.jpg', 'I746556_C1.jpg', 'I746566_C2.jpg', 'I746692_C1.jpg', 'I746556_C2.jpg', 'I746539_C1.jpg', 'I746566_C1.jpg', 'I746524_C2.jpg', 'I746539_C2.jpg', 'I746431_C2.jpg', 'I860432_C2.jpg', 'I860432_C1.jpg', 'I858460_C2.jpg', 'I858460_C1.jpg', 'I836429_C2.jpg', 'I845923_C1.jpg', 'I850562_C1.jpg', 'I849456_C2.jpg', 'I850562_C2.jpg', 'I849456_C1.jpg', 'I845923_C2.jpg', 'I836429_C1.jpg', 'I802100_C1.jpg', 'I782433_C1.jpg', 'I810715_C1.jpg', 'I765390_C2.jpg', 'I765390_C1.jpg', 'I763975_C1.jpg', 'I802100_C2.jpg', 'I810715_C2.jpg', 'I763975_C2.jpg', 'I875628_C1.jpg', 'I862260_C1.jpg', 'I875628_C2.jpg', 'I874390_C2.jpg', 'I874390_C1.jpg', 'I862260_C2.jpg']
print(len(image_ids_array))
# Out:
# 307

# %%
#Cargar Dataset CITOBOT
url="/content/drive/MyDrive/Colab Notebooks/CITOBOT/DATASET/PruebasCITOBOT_Anon.csv"
data1 = pd.read_csv(url, header=0)

data1.columns = ['CASE_NUMBER', 'CASE_ID', 'IMAGE_ID', 'PATH', 'DIAGN']
data1['DIAGN'] = data1['DIAGN'].replace({2: 1})
data1['DIAGN'] = data1['DIAGN'].replace({3: 1})
data1['DIAGN'] = data1['DIAGN'].replace({4: 1})
data1 = data1[data1['DIAGN'] != 5]
print(data1['DIAGN'].value_counts())
data1
# Out:
# 0    303
# 1    168
# Name: DIAGN, dtype: int64
#     CASE_NUMBER  CASE_ID            IMAGE_ID                           PATH  \
# 0      Case 001        2  20230411101755.jpg  PruebasCITOBOT_Anon/Case 001/
# 1      Case 001        2  20230411101702.jpg  PruebasCITOBOT_Anon/Case 001/
# 2      Case 002        2  20230411100907.jpg  PruebasCITOBOT_Anon/Case 002/
# 3      Case 002        2  20230411100934.jpg  PruebasCITOBOT_Anon/Case 002/
# 4      Case 003        2  20230411100207.jpg  PruebasCITOBOT_Anon/Case 003/
# ..          ...      ...                 ...                            ...
# 567    Case 248        2  20230418104244.jpg  PruebasCITOBOT_Anon/Case 248/
# 568    Case 249        2  20230418103711.jpg  PruebasCITOBOT_Anon/Case 249/
# 569    Case 249        2  20230418103638.jpg  PruebasCITOBOT_Anon/Case 249/
# 570    Case 250        2  20230418093117.jpg  PruebasCITOBOT_Anon/Case 250/
# 571    Case 250        2  20230418093028.jpg  PruebasCITOBOT_Anon/Case 250/
#
#      DIAGN
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 567      0
# 568      1
# 569      1
# 570      0
# 571      0
#
# [471 rows x 5 columns]

# %%
#Cargar Dataset WHO
url2="/content/drive/MyDrive/Colab Notebooks/CITOBOT/DATASET/Dataset_WHOSeg.csv"
data2 = pd.read_csv(url2, header=0)

data2.columns = ['CASE_NUMBER', 'CASE_ID', 'IMAGE_ID', 'PATH', 'DIAGN']
data2 = data2.drop(data2[data2.IMAGE_ID == "AAJK5.jpg"].index)
data2['DIAGN'] = data2['DIAGN'].replace({2: 1})
data2['DIAGN'] = data2['DIAGN'].replace({3: 1})
print(data2['DIAGN'].value_counts())
data2
# Out:
# 1    597
# 0    124
# Name: DIAGN, dtype: int64
#      CASE_NUMBER CASE_ID   IMAGE_ID                                  PATH  \
# 0           14.0    AAHE   AAHE.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 1           14.0    AAHE  AAHE0.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 2           14.0    AAHE  AAHE1.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 3           14.0    AAHE  AAHE3.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 4           14.0    AAHE  AAHE4.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# ..           ...     ...        ...                                   ...
# 717        184.0     AEU   AEU1.jpg    WHO_SEG/IARCImageBankVIA/Case 184/
# 718        185.0     ADF   ADF0.jpg    WHO_SEG/IARCImageBankVIA/Case 185/
# 719        185.0     ADF   ADF1.jpg    WHO_SEG/IARCImageBankVIA/Case 185/
# 720        186.0     ABK   ABK0.jpg    WHO_SEG/IARCImageBankVIA/Case 186/
# 721        186.0     ABK   ABK1.jpg    WHO_SEG/IARCImageBankVIA/Case 186/
#
#      DIAGN
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 717      1
# 718      1
# 719      1
# 720      1
# 721      1
#
# [721 rows x 5 columns]

# %%
#Cargar Dataset NCI
url3="/content/drive/MyDrive/Colab Notebooks/CITOBOT/DATASET/trainingDatasetSEG.csv"
data3 = pd.read_csv(url3, header=0)

data3.columns = ['PATIENT_IDR', 'IMAGE_ID', 'AGE_GRP', 'WRST_HIST_AFTER', 'WRST_HIST_AFTER_DT', 'HPV_STATUS', 'HPV_DT', 'TIMEPNT', 'PATH']

#Imagenes que no estan segmentadas =================================
data3 = data3.drop(data3[data3.IMAGE_ID == "I770636_C2.jpg"].index)
data3 = data3.drop(data3[data3.IMAGE_ID == "I862299_C2.jpg"].index)
data3 = data3.drop(data3[data3.IMAGE_ID == "I344141_C2.jpg"].index)
data3 = data3.drop(data3[data3.IMAGE_ID == "I741415_C2.jpg"].index)
data3 = data3.drop(data3[data3.IMAGE_ID == "I584615_C2.jpg"].index)
data3 = data3.drop(data3[data3.IMAGE_ID == "I325700_C1.jpg"].index)
#===================================================================

data3 = data3[((data3['PATH'] == 'training_SEG/Biopsy_Study/') & (data3['WRST_HIST_AFTER'].isin([0, 1]))) | ((data3['PATH'] == 'training_SEG/NHS/') & (data3['WRST_HIST_AFTER'] == 0))]
data3 = data3.rename(columns={'WRST_HIST_AFTER': 'DIAGN'})
data3 = data3.rename(columns={'PATIENT_IDR': 'CASE_NUMBER'})
data3 = data3.rename(columns={'AGE_GRP': 'CASE_ID'})
data3 = data3.drop('WRST_HIST_AFTER_DT', axis=1)
data3 = data3.drop('HPV_STATUS', axis=1)
data3 = data3.drop('HPV_DT', axis=1)
data3 = data3.drop('TIMEPNT', axis=1)
data3 = data3.reindex(columns=['CASE_NUMBER', 'CASE_ID', 'IMAGE_ID', 'PATH', 'DIAGN'])
dataC1 = data3[data3['DIAGN'] == 0]
dataC2 = data3[data3['DIAGN'] == 1]
data_aleatoria = dataC1.sample(n=531)
data_aleatoria2 = dataC2.sample(n=58)
data3 = pd.concat([data_aleatoria, data_aleatoria2])
print(data3['DIAGN'].value_counts())
data3
# Out:
# 0    531
# 1     58
# Name: DIAGN, dtype: int64
#       CASE_NUMBER  CASE_ID        IMAGE_ID                        PATH  DIAGN
# 76652     P899409        5  I325700_C2.jpg           training_SEG/NHS/      0
# 37213     P180975        8  I584038_C2.jpg           training_SEG/NHS/      0
# 194       P438228        2     I240135.jpg  training_SEG/Biopsy_Study/      0
# 73595     P844053        6  I433757_C1.jpg           training_SEG/NHS/      0
# 51197     P430656        6  I471599_C1.jpg           training_SEG/NHS/      0
# ...           ...      ...             ...                         ...    ...
# 459       P894480        2     I247399.jpg  training_SEG/Biopsy_Study/      1
# 37        P176279        3     I599357.jpg  training_SEG/Biopsy_Study/      1
# 204       P453961        3     I618110.jpg  training_SEG/Biopsy_Study/      1
# 319       P661070        3     I404997.jpg  training_SEG/Biopsy_Study/      1
# 242       P531422        3     I555202.jpg  training_SEG/Biopsy_Study/      1
#
# [589 rows x 5 columns]

# %%
#Cargar Dataset Kaggle
url4="/content/drive/MyDrive/Colab Notebooks/CITOBOT/DATASET/kaggleDataset_SEG.csv"
data4 = pd.read_csv(url4, header=0)

data4.columns = ['CASE_NUMBER', 'CASE_ID', 'IMAGE_ID', 'PATH', 'DIAGN']
data4['DIAGN'] = data4['DIAGN'].replace({2: 1})
dataC1 = data4[data4['DIAGN'] == 0]
dataC2 = data4[data4['DIAGN'] == 1]
data_aleatoria = dataC1.sample(n=244)
data_aleatoria2 = dataC2.sample(n=244)
data4 = pd.concat([data_aleatoria, data_aleatoria2])
print(data4['DIAGN'].value_counts())
data4
# Out:
# 0    244
# 1    244
# Name: DIAGN, dtype: int64
#       CASE_NUMBER  CASE_ID  IMAGE_ID                PATH  DIAGN
# 65              0        0  1384.jpg  Kaggle_SEG/Type_1/      0
# 165             0        0   562.jpg  Kaggle_SEG/Type_1/      0
# 71              0        0  1393.jpg  Kaggle_SEG/Type_1/      0
# 38              0        0  1220.jpg  Kaggle_SEG/Type_1/      0
# 208             0        0   783.jpg  Kaggle_SEG/Type_1/      0
# ...           ...      ...       ...                 ...    ...
# 354             0        0  1189.jpg  Kaggle_SEG/Type_2/      1
# 671             0        0   389.jpg  Kaggle_SEG/Type_2/      1
# 412             0        0  1267.jpg  Kaggle_SEG/Type_2/      1
# 1369            0        0   715.jpg  Kaggle_SEG/Type_3/      1
# 621             0        0   302.jpg  Kaggle_SEG/Type_2/      1
#
# [488 rows x 5 columns]

# %%
data = pd.concat([data2, data3])
data
# Out:
#     CASE_NUMBER CASE_ID     IMAGE_ID                                  PATH  \
# 0          14.0    AAHE     AAHE.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 1          14.0    AAHE    AAHE0.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 2          14.0    AAHE    AAHE1.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 3          14.0    AAHE    AAHE3.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# 4          14.0    AAHE    AAHE4.jpg  WHO_SEG/IARCImageBankColpo/Case 014/
# ..          ...     ...          ...                                   ...
# 459     P894480       2  I247399.jpg            training_SEG/Biopsy_Study/
# 37      P176279       3  I599357.jpg            training_SEG/Biopsy_Study/
# 204     P453961       3  I618110.jpg            training_SEG/Biopsy_Study/
# 319     P661070       3  I404997.jpg            training_SEG/Biopsy_Study/
# 242     P531422       3  I555202.jpg            training_SEG/Biopsy_Study/
#
#      DIAGN
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 459      1
# 37       1
# 204      1
# 319      1
# 242      1
#
# [1310 rows x 5 columns]

# %%
#Distribuir clases (2)
print(data['DIAGN'].value_counts())
# Out:
# 0    655
# 1    655
# Name: DIAGN, dtype: int64

# %%
#Balancear Clase de Salida.
#g = data.groupby('DIAGN')
#dataBal = pd.DataFrame(g.apply(lambda x: x.sample(g.size().min()).reset_index(drop=True)))
#data = dataBal
#print(data['DIAGN'].value_counts())

# %%
#Procesar y Cargar Imagenes

def process_image(filepath):
  img = tf.io.read_file(filepath)
  img = tf.image.decode_jpeg(img)
  img = tf.image.resize(img, [224, 224])
  img = tf.image.rgb_to_grayscale(img)  # convertir a escala de grises
  img = tf.image.convert_image_dtype(img, tf.float32)  # convertir a tipo float32
  img /= 255.0  # Normalizar píxeles al rango [0, 1]
  return img

# %%
#Data Augmentation

from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range = 40,
    zoom_range = 0.2,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    horizontal_flip=True,
    vertical_flip = True
)

# %%
#Arquitectura VGGNET
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Activation,Conv2D, MaxPooling2D,Flatten,BatchNormalization
#from keras.utils import np_utils,multi_gpu_model

def modelCompile():
  model = Sequential()
  model.add(Conv2D(64, (3, 3), strides=(1, 1), input_shape=(224,224,1), padding='same', activation='relu',
                    kernel_initializer='uniform'))
  model.add(Conv2D(64, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(128, (3, 2), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(128, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(256, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(Conv2D(512, (3, 3), strides=(1, 1), padding='same', activation='relu', kernel_initializer='uniform'))
  model.add(MaxPooling2D(pool_size=(2, 2)))
  model.add(Flatten())
  model.add(Dense(2048, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(2048, activation='relu'))
  model.add(Dropout(0.5))
  model.add(Dense(2, activation='softmax'))
  #model = multi_gpu_model(model, gpus=2)
  #model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])
  model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), metrics=['accuracy'])
  return model

model = modelCompile()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 64)      640
#
#  conv2d_1 (Conv2D)           (None, 224, 224, 64)      36928
#
#  max_pooling2d (MaxPooling2  (None, 112, 112, 64)      0
#  D)
#
#  conv2d_2 (Conv2D)           (None, 112, 112, 128)     49280
#
#  conv2d_3 (Conv2D)           (None, 112, 112, 128)     147584
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 128)       0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 56, 56, 256)       295168
#
#  conv2d_5 (Conv2D)           (None, 56, 56, 256)       590080
#
#  conv2d_6 (Conv2D)           (None, 56, 56, 256)       590080
#
#  max_pooling2d_2 (MaxPoolin  (None, 28, 28, 256)       0
#  g2D)
#
#  conv2d_7 (Conv2D)           (None, 28, 28, 512)       1180160
#
#  conv2d_8 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  conv2d_9 (Conv2D)           (None, 28, 28, 512)       2359808
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 512)       0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_11 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  conv2d_12 (Conv2D)          (None, 14, 14, 512)       2359808
#
#  max_pooling2d_4 (MaxPoolin  (None, 7, 7, 512)         0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 2048)              51382272
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 2048)              4196352
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_2 (Dense)             (None, 2)                 4098
#
# =================================================================
# Total params: 70271682 (268.07 MB)
# Trainable params: 70271682 (268.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score
import sklearn.metrics as metrics

HOLDOUT = 5

specVec,sensVec,accuVec,precVec,recVec,f1Vec=[],[],[],[],[],[]

for i in range(HOLDOUT):
  print("Iteracion: ",i+1)
  #Conjutnos de Train, Validation y Test
  x_trainPath, x_testPath, y_trainPath, y_testPath = train_test_split(data, data['DIAGN'], test_size=0.2)
  x_trainPath, x_valPath, y_trainPath, y_valPath = train_test_split(x_trainPath, y_trainPath, test_size=0.2)

  y_trainPath = np.array(y_trainPath)
  y_testPath = np.array(y_testPath)
  y_valPath = np.array(y_valPath)

  #Cargar los path de las imagenes para el pipeline
  dataPathDrive = '/content/drive/MyDrive/Colab Notebooks/CITOBOT/DATASET/'
  path_train = dataPathDrive + x_trainPath["PATH"] + x_trainPath['IMAGE_ID']
  path_test = dataPathDrive + x_testPath["PATH"] + x_testPath['IMAGE_ID']
  path_val = dataPathDrive + x_valPath["PATH"] + x_valPath['IMAGE_ID']

  path_train = np.array(path_train)
  path_test = np.array(path_test)
  path_val = np.array(path_val)

  #Convertir en tensores
  data_train = tf.data.Dataset.from_tensor_slices(path_train)
  data_test = tf.data.Dataset.from_tensor_slices(path_test)
  data_val = tf.data.Dataset.from_tensor_slices(path_val)

  #Procesar y Cargar Imagenes
  data_train = data_train.map(process_image)
  data_test = data_test.map(process_image)
  data_val = data_val.map(process_image)

  train = tf.data.Dataset.from_tensor_slices(to_categorical(y_trainPath, 2))
  train = tf.data.Dataset.zip((data_train,train))

  test = tf.data.Dataset.from_tensor_slices(to_categorical(y_testPath, 2))
  test = tf.data.Dataset.zip((data_test,test))

  val = tf.data.Dataset.from_tensor_slices(to_categorical(y_valPath, 2))
  val = tf.data.Dataset.zip((data_val,val))

  AS = train.batch(batch_size=32)
  AST = test.batch(batch_size=32)
  ASV = val.batch(batch_size=32)

  #Aplicar aumento de datos
  x_train = np.array(list(data_train.as_numpy_iterator()))
  y_train = np.array(list(train.as_numpy_iterator()), dtype=object)
  y_train = np.array([y[1] for y in y_train])

  x_val = np.array(list(data_val.as_numpy_iterator()))
  y_val = np.array(list(val.as_numpy_iterator()), dtype=object)
  y_val = np.array([y[1] for y in y_val])

  data_gen_train = datagen.flow(x_train, y_train, batch_size=32)
  data_gen_val = datagen.flow(x_val, y_val, batch_size=32)

  #Cargar Modelo
  model = modelCompile()

  #Entrenar
  callbackMed=tf.keras.callbacks.EarlyStopping(
      monitor='val_loss',
      min_delta=0,
      patience=20,
      verbose=0,
      mode='auto',
      baseline=None,
      restore_best_weights=True
  )

  history = model.fit(data_gen_train, epochs=150, verbose=1, validation_data= data_gen_val, callbacks=[callbackMed,TensorBoard(log_dir='./cnntmp/log')])

  #Grafica Rendimiento ========================================
  fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

  ax1.plot(history.history['loss'])
  ax1.plot(history.history['val_loss'])
  ax1.set_title('Model Loss')
  ax1.set_ylabel('Loss')
  ax1.set_xlabel('Epoch')
  ax1.legend(['train', 'val'], loc='upper left')

  ax2.plot(history.history['accuracy'])
  ax2.plot(history.history['val_accuracy'])
  ax2.set_title('Model Accuracy')
  ax2.set_ylabel('Accuracy')
  ax2.set_xlabel('Epoch')
  ax2.legend(['train', 'val'], loc='upper left')
  plt.show()
  #===========================================================

  model.evaluate(AST)
  pred = model.predict(AST)

  y_testPath = list(y_testPath)
  pred_label=[np.argmax(pred[i]) for i in range(pred.shape[0])]

  mat=confusion_matrix(y_testPath, pred_label)

  tn, fp, fn, tp = mat.ravel()

  specificity = tn / (tn + fp)

  sensitivity = tp / (tp + fn)

  specVec.append(specificity)
  sensVec.append(sensitivity)
  accuVec.append(accuracy_score(y_testPath,pred_label))
  precVec.append(precision_score(y_testPath,pred_label,average=None,zero_division=0))
  recVec.append(recall_score(y_testPath,pred_label,average=None,zero_division=0))
  f1Vec.append(f1_score(y_testPath,pred_label,average=None,zero_division=0))

  print(mat)
  print("Specificity: ",specificity)
  print("Sensitivity: ",sensitivity)
  print("Accuracy: ",accuracy_score(y_testPath,pred_label))
  print("Precision: ",precision_score(y_testPath,pred_label,average=None,zero_division=0))
  print("Recall:    ",recall_score(y_testPath,pred_label,average=None,zero_division=0))
  print("F1score:   ",f1_score(y_testPath,pred_label,average=None,zero_division=0))
  print("=====================================")

print("Media")
print("Specificity: ",np.mean(specVec)," | ","Sensitivity: ",np.mean(sensVec))
print("Accuracy: ",np.mean(accuVec)," | ","Precision: ",np.mean(precVec)," | ","Recall: ",np.mean(recVec)," | ","F1score: ",np.mean(f1Vec))
print()
print("Desviacion")
print("Specificity: ",np.std(specVec)," | ","Sensitivity: ",np.std(sensVec))
print("Accuracy: ",np.std(accuVec)," | ","Precision: ",np.std(precVec)," | ","Recall: ",np.std(recVec)," | ","F1score: ",np.std(f1Vec))
# Out:
# Iteracion:  1
# Epoch 1/150
# 27/27 [==============================] - 42s 704ms/step - loss: 0.6004 - accuracy: 0.6695 - val_loss: 0.5525 - val_accuracy: 0.8238
# Epoch 2/150
# 27/27 [==============================] - 12s 460ms/step - loss: 0.4884 - accuracy: 0.8103 - val_loss: 0.4553 - val_accuracy: 0.7905
# Epoch 3/150
# 27/27 [==============================] - 13s 468ms/step - loss: 0.4382 - accuracy: 0.8270 - val_loss: 0.4424 - val_accuracy: 0.8095
# Epoch 4/150
# 27/27 [==============================] - 13s 479ms/step - loss: 0.4285 - accuracy: 0.8246 - val_loss: 0.4142 - val_accuracy: 0.8381
# Epoch 5/150
# 27/27 [==============================] - 13s 475ms/step - loss: 0.4451 - accuracy: 0.8162 - val_loss: 0.4107 - val_accuracy: 0.7810
# Epoch 6/150
# 27/27 [==============================] - 12s 458ms/step - loss: 0.4351 - accuracy: 0.8222 - val_loss: 0.4570 - val_accuracy: 0.8190
# Epoch 7/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4210 - accuracy: 0.8317 - val_loss: 0.4961 - val_accuracy: 0.7905
# Epoch 8/150
# 27/27 [==============================] - 12s 460ms/step - loss: 0.4134 - accuracy: 0.8329 - val_loss: 0.3946 - val_accuracy: 0.8190
# Epoch 9/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4014 - accuracy: 0.8341 - val_loss: 0.5076 - val_accuracy: 0.8238
# Epoch 10/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4005 - accuracy: 0.8305 - val_loss: 0.4200 - val_accuracy: 0.7905
# Epoch 11/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.4242 - accuracy: 0.8353 - val_loss: 0.4029 - val_accuracy: 0.8190
# Epoch 12/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4108 - accuracy: 0.8294 - val_loss: 0.5113 - val_accuracy: 0.7810
# Epoch 13/150
# 27/27 [==============================] - 12s 455ms/step - loss: 0.3854 - accuracy: 0.8437 - val_loss: 0.3972 - val_accuracy: 0.8190
# Epoch 14/150
# 27/27 [==============================] - 13s 462ms/step - loss: 0.4000 - accuracy: 0.8162 - val_loss: 0.3850 - val_accuracy: 0.8238
# Epoch 15/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.
150
# 27/27 [==============================] - 12s 461ms/step - loss: 0.3618 - accuracy: 0.8532 - val_loss: 0.4700 - val_accuracy: 0.7762
# Epoch 43/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3799 - accuracy: 0.8461 - val_loss: 0.3707 - val_accuracy: 0.8524
# Epoch 44/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3407 - accuracy: 0.8652 - val_loss: 0.3819 - val_accuracy: 0.8190
# Epoch 45/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3388 - accuracy: 0.8556 - val_loss: 0.4229 - val_accuracy: 0.8143
# Epoch 46/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3610 - accuracy: 0.8484 - val_loss: 0.4187 - val_accuracy: 0.8095
# Epoch 47/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3535 - accuracy: 0.8675 - val_loss: 0.3684 - val_accuracy: 0.8333
# Epoch 48/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3493 - accuracy: 0.8604 - val_loss: 0.3787 - val_accuracy: 0.8333
# Epoch 49/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3460 - accuracy: 0.8580 - val_loss: 0.3545 - val_accuracy: 0.8381
# Epoch 50/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3473 - accuracy: 0.8616 - val_loss: 0.4357 - val_accuracy: 0.7952
# Epoch 51/150
# 27/27 [==============================] - 13s 462ms/step - loss: 0.3531 - accuracy: 0.8532 - val_loss: 0.3659 - val_accuracy: 0.8381
# 9/9 [==============================] - 26s 3s/step - loss: 0.4273 - accuracy: 0.8015
# 9/9 [==============================] - 4s 465ms/step
# [[100  45]
#  [  7 110]]
# Specificity:  0.6896551724137931
# Sensitivity:  0.9401709401709402
# Accuracy:  0.8015267175572519
# Precision:  [0.93457944 0.70967742]
# Recall:     [0.68965517 0.94017094]
# F1score:    [0.79365079 0.80882353]
# =====================================
# Iteracion:  2
# Epoch 1/150
# 27/27 [==============================] - 17s 488ms/step - loss: 0.6228 - accuracy: 0.6396 - val_loss: 0.4760 - val_accuracy: 0.8381
# Epoch 2/150
# 27/27 [==============================] - 13s 478ms/step - loss: 0.4875 - accuracy: 0.8126 - val_loss: 0.4212 - val_accuracy: 0.8238
# Epoch 3/150
# 27/27 [==============================] - 13s 480ms/step - loss: 0.4802 - accuracy: 0.8174 - val_loss: 0.4187 - val_accuracy: 0.8095
# Epoch 4/150
# 27/27 [==============================] - 13s 466ms/step - loss: 0.4885 - accuracy: 0.7983 - val_loss: 0.4081 - val_accuracy: 0.8476
# Epoch 5/150
# 27/27 [==============================] - 12s 460ms/step - loss: 0.4426 - accuracy: 0.8162 - val_loss: 0.3948 - val_accuracy: 0.8381
# Epoch 6/150
# 27/27 [==============================] - 12s 458ms/step - loss: 0.4424 - accuracy: 0.8186 - val_loss: 0.3843 - val_accuracy: 0.8190
# Epoch 7/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4192 - accuracy: 0.8353 - val_loss: 0.4029 - val_accuracy: 0.8190
# Epoch 8/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4313 - accuracy: 0.8234 - val_loss: 0.4066 - val_accuracy: 0.8143
# Epoch 9/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.4244 - accuracy: 0.8294 - val_loss: 0.4184 - val_accuracy: 0.8095
# Epoch 10/150
# 27/27 [==============================] - 12s 457ms/step - loss: 0.4168 - accuracy: 0.8258 - val_loss: 0.4301 - val_accuracy: 0.8190
# Epoch 11/150
# 27/27 [==============================] - 13s 463ms/step - loss: 0.4090 - accuracy: 0.8341 - val_loss: 0.3561 - val_accuracy: 0.8381
# Epoch 12/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.3903 - accuracy: 0.8401 - val_loss: 0.3796 - val_accuracy: 0.8333
# Epoch 13/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4081 - accuracy: 0.8389 - val_loss: 0.4064 - val_accuracy: 0.8238
# Epoch 14/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.
150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3506 - accuracy: 0.8508 - val_loss: 0.3351 - val_accuracy: 0.8667
# Epoch 72/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3521 - accuracy: 0.8425 - val_loss: 0.3218 - val_accuracy: 0.8714
# Epoch 73/150
# 27/27 [==============================] - 12s 463ms/step - loss: 0.3668 - accuracy: 0.8365 - val_loss: 0.3206 - val_accuracy: 0.8762
# Epoch 74/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3634 - accuracy: 0.8389 - val_loss: 0.3336 - val_accuracy: 0.8667
# Epoch 75/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3390 - accuracy: 0.8449 - val_loss: 0.2904 - val_accuracy: 0.8762
# Epoch 76/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3503 - accuracy: 0.8461 - val_loss: 0.2890 - val_accuracy: 0.8857
# Epoch 77/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.3450 - accuracy: 0.8437 - val_loss: 0.3640 - val_accuracy: 0.8238
# Epoch 78/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3579 - accuracy: 0.8449 - val_loss: 0.3132 - val_accuracy: 0.8714
# Epoch 79/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3467 - accuracy: 0.8473 - val_loss: 0.2991 - val_accuracy: 0.8762
# Epoch 80/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3486 - accuracy: 0.8484 - val_loss: 0.3039 - val_accuracy: 0.8762
# Epoch 81/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3573 - accuracy: 0.8413 - val_loss: 0.3359 - val_accuracy: 0.8810
# Epoch 82/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3574 - accuracy: 0.8473 - val_loss: 0.2948 - val_accuracy: 0.8810
# Epoch 83/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3314 - accuracy: 0.8496 - val_loss: 0.3227 - val_accuracy: 0.8762
# Epoch 84/150
# 27/27 [==============================] - 13s 464ms/step - loss: 0.3411 - accuracy: 0.8449 - val_loss: 0.3299 - val_accuracy: 0.8667
# 9/9 [==============================] - 4s 457ms/step - loss: 0.3640 - accuracy: 0.8397
# 9/9 [==============================] - 4s 449ms/step
# [[104  34]
#  [  8 116]]
# Specificity:  0.7536231884057971
# Sensitivity:  0.9354838709677419
# Accuracy:  0.8396946564885496
# Precision:  [0.92857143 0.77333333]
# Recall:     [0.75362319 0.93548387]
# F1score:    [0.832      0.84671533]
# =====================================
# Iteracion:  4
# Epoch 1/150
# 27/27 [==============================] - 17s 489ms/step - loss: 0.6250 - accuracy: 0.6360 - val_loss: 0.5094 - val_accuracy: 0.8143
# Epoch 2/150
# 27/27 [==============================] - 13s 481ms/step - loss: 0.5511 - accuracy: 0.7327 - val_loss: 0.5556 - val_accuracy: 0.6667
# Epoch 3/150
# 27/27 [==============================] - 13s 479ms/step - loss: 0.5061 - accuracy: 0.7673 - val_loss: 0.4661 - val_accuracy: 0.8143
# Epoch 4/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.4829 - accuracy: 0.7971 - val_loss: 0.4916 - val_accuracy: 0.7952
# Epoch 5/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.4829 - accuracy: 0.7876 - val_loss: 0.4865 - val_accuracy: 0.8048
# Epoch 6/150
# 27/27 [==============================] - 12s 457ms/step - loss: 0.4477 - accuracy: 0.8186 - val_loss: 0.4490 - val_accuracy: 0.8476
# Epoch 7/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.4228 - accuracy: 0.8365 - val_loss: 0.4405 - val_accuracy: 0.8286
# Epoch 8/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4477 - accuracy: 0.8138 - val_loss: 0.4433 - val_accuracy: 0.8381
# Epoch 9/150
# 27/27 [==============================] - 13s 465ms/step - loss: 0.4311 - accuracy: 0.8222 - val_loss: 0.4092 - val_accuracy: 0.8476
# Epoch 10/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.4149 - accuracy: 0.8294 - val_loss: 0.4249 - val_accuracy: 0.8429
# Epoch 11/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4569 - accuracy: 0.8091 - val_loss: 0.4677 - val_accuracy: 0.7952
# Epoch 12/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4815 - accuracy: 0.7840 - val_loss: 0.4617 - val_accuracy: 0.8095
# Epoch 13/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4241 - accuracy: 0.8162 - val_loss: 0.4728 - val_accuracy: 0.8048
# Epoch 14/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4516 - accuracy: 0.8031 - val_loss: 0.4262 - val_accuracy: 0.8476
# Epoch 15/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4378 - accuracy: 0.8115 - val_loss: 0.4253 - val_accuracy: 0.8333
# Epoch 16/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4143 - accuracy: 0.8305 - val_loss: 0.4245 - val_accuracy: 0.8381
# Epoch 17/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4085 - accuracy: 0.8294 - val_loss: 0.4429 - val_accuracy: 0.8143
# Epoch 18/150
# 27/27 [==============================] - 13s 462ms/step - loss: 0.4118 - accuracy: 0.8282 - val_loss: 0.3995 - val_accuracy: 0.8524
# Epoch 19/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.4215 - accuracy: 0.8282 - val_loss: 0.4215 - val_accuracy: 0.8381
# Epoch 20/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4062 - accuracy: 0.8365 - val_loss: 0.4298 - val_accuracy: 0.8238
# Epoch 21/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4019 - accuracy: 0.8377 - val_loss: 0.4217 - val_accuracy: 0.8333
# Epoch 22/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4119 - accuracy: 0.8305 - val_loss: 0.4277 - val_accuracy: 0.8286
# Epoch 23/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4013 - accuracy: 0.8329 - val_loss: 0.4094 - val_accuracy: 0.8476
# Epoch 24/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4299 - accuracy: 0.8055 - val_loss: 0.4190 - val_accuracy: 0.8429
# Epoch 25/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.4190 - accuracy: 0.8341 - val_loss: 0.4166 - val_accuracy: 0.8524
# Epoch 26/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.4124 - accuracy: 0.8282 - val_loss: 0.4266 - val_accuracy: 0.8238
# Epoch 27/150
# 27/27 [==============================] - 12s 461ms/step - loss: 0.3935 - accuracy: 0.8353 - val_loss: 0.3919 - val_accuracy: 0.8429
# Epoch 28/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4040 - accuracy: 0.8270 - val_loss: 0.4288 - val_accuracy: 0.8190
# Epoch 29/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3925 - accuracy: 0.8282 - val_loss: 0.4326 - val_accuracy: 0.8476
# Epoch 30/150
# 27/27 [==============================] - 12s 461ms/step - loss: 0.4039 - accuracy: 0.8389 - val_loss: 0.4259 - val_accuracy: 0.8333
# Epoch 31/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3716 - accuracy: 0.8365 - val_loss: 0.4855 - val_accuracy: 0.7714
# Epoch 32/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.4096 - accuracy: 0.8282 - val_loss: 0.4048 - val_accuracy: 0.8429
# Epoch 33/150
# 27/27 [==============================] - 12s 460ms/step - loss: 0.4025 - accuracy: 0.8270 - val_loss: 0.3741 - val_accuracy: 0.8524
# Epoch 34/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.3799 - accuracy: 0.8437 - val_loss: 0.3694 - val_accuracy: 0.8524
# Epoch 35/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3957 - accuracy: 0.8317 - val_loss: 0.3885 - val_accuracy: 0.8524
# Epoch 36/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3772 - accuracy: 0.8377 - val_loss: 0.4090 - val_accuracy: 0.8333
# Epoch 37/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3971 - accuracy: 0.8341 - val_loss: 0.4126 - val_accuracy: 0.8238
# Epoch 38/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3711 - accuracy: 0.8389 - val_loss: 0.3761 - val_accuracy: 0.8524
# Epoch 39/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3761 - accuracy: 0.8377 - val_loss: 0.3838 - val_accuracy: 0.8571
# Epoch 40/150
# 27/27 [==============================] - 12s 454ms/step - loss: 0.
150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3468 - accuracy: 0.8640 - val_loss: 0.4217 - val_accuracy: 0.8333
# Epoch 71/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3448 - accuracy: 0.8484 - val_loss: 0.3350 - val_accuracy: 0.8524
# Epoch 72/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3292 - accuracy: 0.8544 - val_loss: 0.3860 - val_accuracy: 0.8524
# Epoch 73/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.3535 - accuracy: 0.8544 - val_loss: 0.3201 - val_accuracy: 0.8571
# Epoch 74/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3206 - accuracy: 0.8628 - val_loss: 0.3559 - val_accuracy: 0.8381
# Epoch 75/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3290 - accuracy: 0.8496 - val_loss: 0.3465 - val_accuracy: 0.8333
# Epoch 76/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3205 - accuracy: 0.8556 - val_loss: 0.3702 - val_accuracy: 0.8286
# Epoch 77/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3215 - accuracy: 0.8675 - val_loss: 0.4052 - val_accuracy: 0.8286
# Epoch 78/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3300 - accuracy: 0.8556 - val_loss: 0.3448 - val_accuracy: 0.8524
# Epoch 79/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3279 - accuracy: 0.8675 - val_loss: 0.3412 - val_accuracy: 0.8524
# Epoch 80/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3122 - accuracy: 0.8687 - val_loss: 0.3252 - val_accuracy: 0.8429
# Epoch 81/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3125 - accuracy: 0.8580 - val_loss: 0.3783 - val_accuracy: 0.8238
# Epoch 82/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3242 - accuracy: 0.8604 - val_loss: 0.3659 - val_accuracy: 0.8286
# Epoch 83/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3080 - accuracy: 0.8592 - val_loss: 0.3388 - val_accuracy: 0.8667
# Epoch 84/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3419 - accuracy: 0.8568 - val_loss: 0.3407 - val_accuracy: 0.8333
# Epoch 85/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3207 - accuracy: 0.8556 - val_loss: 0.3637 - val_accuracy: 0.8476
# Epoch 86/150
# 27/27 [==============================] - 12s 458ms/step - loss: 0.3061 - accuracy: 0.8628 - val_loss: 0.3179 - val_accuracy: 0.8571
# Epoch 87/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3279 - accuracy: 0.8508 - val_loss: 0.3651 - val_accuracy: 0.8429
# Epoch 88/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3281 - accuracy: 0.8640 - val_loss: 0.3413 - val_accuracy: 0.8476
# Epoch 89/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3201 - accuracy: 0.8580 - val_loss: 0.3466 - val_accuracy: 0.8476
# Epoch 90/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.2982 - accuracy: 0.8663 - val_loss: 0.3771 - val_accuracy: 0.8381
# Epoch 91/150
# 27/27 [==============================] - 12s 458ms/step - loss: 0.3032 - accuracy: 0.8640 - val_loss: 0.3130 - val_accuracy: 0.8667
# Epoch 92/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.2974 - accuracy: 0.8687 - val_loss: 0.3486 - val_accuracy: 0.8667
# Epoch 93/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3034 - accuracy: 0.8675 - val_loss: 0.3279 - val_accuracy: 0.8571
# Epoch 94/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3167 - accuracy: 0.8675 - val_loss: 0.3922 - val_accuracy: 0.8143
# Epoch 95/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3054 - accuracy: 0.8580 - val_loss: 0.3324 - val_accuracy: 0.8381
# Epoch 96/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3203 - accuracy: 0.8580 - val_loss: 0.3266 - val_accuracy: 0.8619
# Epoch 97/150
# 27/27 [==============================] - 12s 446ms/step - loss: 0.3148 - accuracy: 0.8663 - val_loss: 0.3634 - val_accuracy: 0.8524
# Epoch 98/150
# 27/27 [==============================] - 12s 447ms/step - loss: 0.3100 - accuracy: 0.8628 - val_loss: 0.3557 - val_accuracy: 0.8619
# Epoch 99/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3003 - accuracy: 0.8747 - val_loss: 0.3309 - val_accuracy: 0.8619
# Epoch 100/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3293 - accuracy: 0.8616 - val_loss: 0.3469 - val_accuracy: 0.8429
# Epoch 101/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.3069 - accuracy: 0.8699 - val_loss: 0.3124 - val_accuracy: 0.8476
# Epoch 102/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.2970 - accuracy: 0.8711 - val_loss: 0.3055 - val_accuracy: 0.8619
# Epoch 103/150
# 27/27 [==============================] - 12s 460ms/step - loss: 0.2910 - accuracy: 0.8735 - val_loss: 0.3431 - val_accuracy: 0.8476
# Epoch 104/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.3055 - accuracy: 0.8616 - val_loss: 0.3284 - val_accuracy: 0.8524
# Epoch 105/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3238 - accuracy: 0.8616 - val_loss: 0.3485 - val_accuracy: 0.8476
# Epoch 106/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3017 - accuracy: 0.8675 - val_loss: 0.3401 - val_accuracy: 0.8286
# Epoch 107/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3102 - accuracy: 0.8675 - val_loss: 0.3140 - val_accuracy: 0.8476
# Epoch 108/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.2958 - accuracy: 0.8759 - val_loss: 0.3293 - val_accuracy: 0.8381
# Epoch 109/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.2900 - accuracy: 0.8735 - val_loss: 0.3109 - val_accuracy: 0.8667
# Epoch 110/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3135 - accuracy: 0.8592 - val_loss: 0.3666 - val_accuracy: 0.8381
# Epoch 111/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3386 - accuracy: 0.8532 - val_loss: 0.3350 - val_accuracy: 0.8333
# Epoch 112/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3123 - accuracy: 0.8592 - val_loss: 0.3512 - val_accuracy: 0.8286
# Epoch 113/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3057 - accuracy: 0.8640 - val_loss: 0.3148 - val_accuracy: 0.8429
# Epoch 114/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.3049 - accuracy: 0.8628 - val_loss: 0.3302 - val_accuracy: 0.8286
# Epoch 115/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.2952 - accuracy: 0.8747 - val_loss: 0.3488 - val_accuracy: 0.8476
# Epoch 116/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.2788 - accuracy: 0.8747 - val_loss: 0.3410 - val_accuracy: 0.8571
# Epoch 117/150
# 27/27 [==============================] - 12s 449ms/step - loss: 0.2974 - accuracy: 0.8640 - val_loss: 0.3668 - val_accuracy: 0.8190
# Epoch 118/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3172 - accuracy: 0.8628 - val_loss: 0.3202 - val_accuracy: 0.8381
# Epoch 119/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.2938 - accuracy: 0.8687 - val_loss: 0.3221 - val_accuracy: 0.8524
# Epoch 120/150
# 27/27 [==============================] - 12s 450ms/step - loss: 0.3001 - accuracy: 0.8807 - val_loss: 0.3535 - val_accuracy: 0.8238
# Epoch 121/150
# 27/27 [==============================] - 12s 448ms/step - loss: 0.2925 - accuracy: 0.8699 - val_loss: 0.3982 - val_accuracy: 0.8429
# Epoch 122/150
# 27/27 [==============================] - 12s 459ms/step - loss: 0.3106 - accuracy: 0.8556 - val_loss: 0.3318 - val_accuracy: 0.8619
# 9/9 [==============================] - 4s 395ms/step - loss: 0.4157 - accuracy: 0.8588
# 9/9 [==============================] - 4s 393ms/step
# [[102  24]
#  [ 13 123]]
# Specificity:  0.8095238095238095
# Sensitivity:  0.9044117647058824
# Accuracy:  0.8587786259541985
# Precision:  [0.88695652 0.83673469]
# Recall:     [0.80952381 0.90441176]
# F1score:    [0.84647303 0.86925795]
# =====================================
# Iteracion:  5
# Epoch 1/150
150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.3838 - accuracy: 0.8317 - val_loss: 0.4376 - val_accuracy: 0.8286
# Epoch 26/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.3960 - accuracy: 0.8377 - val_loss: 0.4199 - val_accuracy: 0.8238
# Epoch 27/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.3886 - accuracy: 0.8353 - val_loss: 0.4338 - val_accuracy: 0.8190
# Epoch 28/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3643 - accuracy: 0.8425 - val_loss: 0.4150 - val_accuracy: 0.8238
# Epoch 29/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3799 - accuracy: 0.8365 - val_loss: 0.4285 - val_accuracy: 0.8333
# Epoch 30/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.4009 - accuracy: 0.8246 - val_loss: 0.4682 - val_accuracy: 0.8048
# Epoch 31/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3740 - accuracy: 0.8377 - val_loss: 0.4523 - val_accuracy: 0.7952
# Epoch 32/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3569 - accuracy: 0.8580 - val_loss: 0.4200 - val_accuracy: 0.8143
# Epoch 33/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.3639 - accuracy: 0.8329 - val_loss: 0.4409 - val_accuracy: 0.8143
# Epoch 34/150
# 27/27 [==============================] - 12s 453ms/step - loss: 0.3441 - accuracy: 0.8449 - val_loss: 0.4914 - val_accuracy: 0.8143
# Epoch 35/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3797 - accuracy: 0.8377 - val_loss: 0.4114 - val_accuracy: 0.8381
# Epoch 36/150
# 27/27 [==============================] - 12s 451ms/step - loss: 0.3693 - accuracy: 0.8389 - val_loss: 0.4276 - val_accuracy: 0.8238
# Epoch 37/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3722 - accuracy: 0.8317 - val_loss: 0.4088 - val_accuracy: 0.8190
# Epoch 38/150
# 27/27 [==============================] - 12s 452ms/step - loss: 0.3602 - accuracy: 0.8377 - val_loss: 0.4350 - val_accuracy: 0.8429
# Epoch 39/150
# 27/27 [==============================] - 12s 455ms/step - loss: 0.3594 - accuracy: 0.8484 - val_loss: 0.4350 - val_accuracy: 0.8190
# Epoch 40/150
# 27/27 [==============================] - 12s 462ms/step - loss: 0.3857 - accuracy: 0.8437 - val_loss: 0.4594 - val_accuracy: 0.8238
# Epoch 41/150
# 27/27 [==============================] - 13s 465ms/step - loss: 0.3690 - accuracy: 0.8341 - val_loss: 0.4167 - val_accuracy: 0.8190
# 9/9 [==============================] - 3s 377ms/step - loss: 0.3594 - accuracy: 0.8626
# 9/9 [==============================] - 3s 389ms/step
# [[ 92  30]
#  [  6 134]]
# Specificity:  0.7540983606557377
# Sensitivity:  0.9571428571428572
# Accuracy:  0.8625954198473282
# Precision:  [0.93877551 0.81707317]
# Recall:     [0.75409836 0.95714286]
# F1score:    [0.83636364 0.88157895]
# =====================================
# Media
# Specificity:  0.7533180906959515  |  Sensitivity:  0.932404292612522
# Accuracy:  0.8412213740458014  |  Precision:  0.8531810223173112  |  Recall:  0.8428611916542368  |  F1score:  0.8399010291389587
#
# Desviacion
# Specificity:  0.038087667660994466  |  Sensitivity:  0.017452938212255176
# Accuracy:  0.02167186193370747  |  Precision:  0.07431578139417418  |  Recall:  0.09431651323746672  |  F1score:  0.025163359423647735

# %%
#import tensorflow as tf

#converter = tf.lite.TFLiteConverter.from_keras_model(model)
#tflite_model = converter.convert()

#with open("model.tflite", 'wb') as f:
#  f.write(tflite_model)
